# %% [markdown]
# # Starting to work with the data #

# %%
url= "https_address of the url"
df=pd.read_csv("url")
df.head()

# %%
#adding headers, when loading a CSV, as it usually doenst have headers.
headers = ["x","y","z"]

# %%
#replace headers and check the dataFrame
df.columns=headers
df.columns

# %%
#replacing the ? with the Nan, so that the Dropna() function can work
df1=df.replace('?',np.NaN)

df=df1.dropna(subset = ["x"], axis=0
#axis=0 refers to the indexes(rows), axis=1 refers to the collumns

# %%
#saving a CSV
df.to_csv("name_project.csv", index=False)
#index=False means that the row names wont be written

# %% [markdown]
# # Data Wrangling #

# %%
#Identify and count the missing values, which collumns have missing values, and if the missing values are misssing or not. 
missing_data=df.insull()
missing_data.head(5)
for collumn in missing_data.columns.values.tolist():
    print(column)
    print (missing_data[column]).value_counts()
    print ("")

# %% [markdown]
# # Binning - Diving a certain collumn into sections #

# %%
# 1) change the collumn to the proper type
    df["x"]=df["x"].astype(int, opy=True)


# 2) Divide into bins
    bins=np.linespace(min(df["x"]), max(df["x"]), 4) # since we want 3 sections, with max, min and middle, then we use the min/max function. furthermore, as we need 3 sections, at the end we add 4. 


# 3) name the groups
    group names = ["high", "low", "medium"]


# 4) distribute each value from the collumn into their groups
